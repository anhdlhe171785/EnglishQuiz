-- %% [markdown]
-- # [EnglishQuiz]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [EnglishQuiz]    Script Date: 8/20/2025 10:22:37 PM ******/
CREATE DATABASE [EnglishQuiz]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'EnglishQuiz', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\EnglishQuiz.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'EnglishQuiz_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\EnglishQuiz_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [EnglishQuiz] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [EnglishQuiz].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [EnglishQuiz] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [EnglishQuiz] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [EnglishQuiz] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [EnglishQuiz] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [EnglishQuiz] SET ARITHABORT OFF 
GO
ALTER DATABASE [EnglishQuiz] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [EnglishQuiz] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [EnglishQuiz] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [EnglishQuiz] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [EnglishQuiz] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [EnglishQuiz] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [EnglishQuiz] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [EnglishQuiz] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [EnglishQuiz] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [EnglishQuiz] SET  ENABLE_BROKER 
GO
ALTER DATABASE [EnglishQuiz] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [EnglishQuiz] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [EnglishQuiz] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [EnglishQuiz] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [EnglishQuiz] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [EnglishQuiz] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [EnglishQuiz] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [EnglishQuiz] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [EnglishQuiz] SET  MULTI_USER 
GO
ALTER DATABASE [EnglishQuiz] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [EnglishQuiz] SET DB_CHAINING OFF 
GO
ALTER DATABASE [EnglishQuiz] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [EnglishQuiz] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [EnglishQuiz] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [EnglishQuiz] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [EnglishQuiz] SET QUERY_STORE = ON
GO
ALTER DATABASE [EnglishQuiz] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[ExamHistories]

-- %%
USE [EnglishQuiz]
GO

-- %%
/****** Object:  Table [dbo].[ExamHistories]    Script Date: 8/20/2025 10:22:37 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ExamHistories](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [int] NULL,
	[ExamId] [int] NULL,
	[Score] [int] NULL,
	[DateTaken] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Exams]

-- %%
/****** Object:  Table [dbo].[Exams]    Script Date: 8/20/2025 10:22:37 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Exams](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Title] [nvarchar](100) NOT NULL,
	[Description] [nvarchar](255) NULL,
	[IsRandom] [bit] NULL,
	[CreatedAt] [datetime] NULL,
	[IsVisible] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Questions]

-- %%
/****** Object:  Table [dbo].[Questions]    Script Date: 8/20/2025 10:22:37 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Questions](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ExamId] [int] NULL,
	[Content] [nvarchar](max) NOT NULL,
	[OptionA] [nvarchar](max) NULL,
	[OptionB] [nvarchar](max) NULL,
	[OptionC] [nvarchar](max) NULL,
	[OptionD] [nvarchar](max) NULL,
	[CorrectOption] [char](1) NOT NULL,
	[Category] [nvarchar](100) NULL,
	[CreatedAt] [datetime] NULL,
	[OptionE] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserAnswers]

-- %%
/****** Object:  Table [dbo].[UserAnswers]    Script Date: 8/20/2025 10:22:37 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserAnswers](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ExamHistoryId] [int] NULL,
	[QuestionId] [int] NULL,
	[SelectedOption] [char](1) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 8/20/2025 10:22:37 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [nvarchar](50) NOT NULL,
	[Email] [nvarchar](100) NULL,
	[PasswordHash] [nvarchar](255) NOT NULL,
	[Role] [nvarchar](20) NOT NULL,
	[Address] [nvarchar](255) NULL,
	[Phone] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__ExamHisto__DateT__3F466844]

-- %%
ALTER TABLE [dbo].[ExamHistories] ADD  DEFAULT (getdate()) FOR [DateTaken]
GO

-- %% [markdown]
-- # [DF__Exams__IsRandom__403A8C7D]

-- %%
ALTER TABLE [dbo].[Exams] ADD  DEFAULT ((0)) FOR [IsRandom]
GO

-- %% [markdown]
-- # [DF__Exams__CreatedAt__412EB0B6]

-- %%
ALTER TABLE [dbo].[Exams] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Exams__IsVisible__5AEE82B9]

-- %%
ALTER TABLE [dbo].[Exams] ADD  DEFAULT ((1)) FOR [IsVisible]
GO

-- %% [markdown]
-- # [DF__Questions__Creat__4222D4EF]

-- %%
ALTER TABLE [dbo].[Questions] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [FK__ExamHisto__ExamI__4316F928]

-- %%
ALTER TABLE [dbo].[ExamHistories]  WITH CHECK ADD FOREIGN KEY([ExamId])
REFERENCES [dbo].[Exams] ([Id])
GO

-- %% [markdown]
-- # [FK__ExamHisto__UserI__440B1D61]

-- %%
ALTER TABLE [dbo].[ExamHistories]  WITH CHECK ADD FOREIGN KEY([UserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Questions__ExamI__44FF419A]

-- %%
ALTER TABLE [dbo].[Questions]  WITH CHECK ADD FOREIGN KEY([ExamId])
REFERENCES [dbo].[Exams] ([Id])
GO

-- %% [markdown]
-- # [FK__UserAnswe__ExamH__45F365D3]

-- %%
ALTER TABLE [dbo].[UserAnswers]  WITH CHECK ADD FOREIGN KEY([ExamHistoryId])
REFERENCES [dbo].[ExamHistories] ([Id])
GO

-- %% [markdown]
-- # [FK__UserAnswe__Quest__46E78A0C]

-- %%
ALTER TABLE [dbo].[UserAnswers]  WITH CHECK ADD FOREIGN KEY([QuestionId])
REFERENCES [dbo].[Questions] ([Id])
GO

-- %% [markdown]
-- # [CK_Questions_CorrectOption]

-- %%
ALTER TABLE [dbo].[Questions]  WITH CHECK ADD  CONSTRAINT [CK_Questions_CorrectOption] CHECK  (([CorrectOption]='E' OR [CorrectOption]='D' OR [CorrectOption]='C' OR [CorrectOption]='B' OR [CorrectOption]='A'))
GO
ALTER TABLE [dbo].[Questions] CHECK CONSTRAINT [CK_Questions_CorrectOption]
GO

-- %% [markdown]
-- # [CK_UserAnswers_SelectedOption]

-- %%
ALTER TABLE [dbo].[UserAnswers]  WITH CHECK ADD  CONSTRAINT [CK_UserAnswers_SelectedOption] CHECK  (([SelectedOption]=N'X' OR [SelectedOption]=N'E' OR [SelectedOption]=N'D' OR [SelectedOption]=N'C' OR [SelectedOption]=N'B' OR [SelectedOption]=N'A'))
GO
ALTER TABLE [dbo].[UserAnswers] CHECK CONSTRAINT [CK_UserAnswers_SelectedOption]
GO

-- %% [markdown]
-- # [CK__Users__Role__49C3F6B7]

-- %%
ALTER TABLE [dbo].[Users]  WITH CHECK ADD CHECK  (([Role]='Admin' OR [Role]='User'))
GO

-- %% [markdown]
-- # [EnglishQuiz]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [EnglishQuiz] SET  READ_WRITE 
GO
